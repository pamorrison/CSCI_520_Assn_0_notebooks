# %%
if __name__=='__main__':
    import imageio
    import matplotlib.pyplot as plt
    # %matplotlib inline
    
    # PLEASE ENTER FILE LOCATION HERE
    file_location='/Users/PaulMorrison/Documents/puzzlemastersmall.jpg'
    
    pic=imageio.imread(file_location)
    plt.figure(figsize=(15,15))
    
    plt.imshow(pic)

# %%
print('Type of the image : ',type(pic))
print()
print('Shape of the image : {}'.format(pic.shape))
print('Image Hight {}'.format(pic.shape[0]))
print('Image Width {}'.format(pic.shape[1]))
print('Dimension of Image {}'.format(pic.ndim))
# Out:
# Type of the image :  <class 'imageio.core.util.Array'>
#
# Shape of the image : (237, 237, 3)
# Image Hight 237
# Image Width 237
# Dimension of Image 3

# %%
print('Image size {}'.format(pic.size))
print('Maximum RGB value in this image {}'.format(pic.max()))
print('Minimum RGB value in this image {}'.format(pic.min()))
# Out:
# Image size 168507
# Maximum RGB value in this image 255
# Minimum RGB value in this image 0

# %%
print('Value of only R channel {}'.format(pic[ 100, 50, 0]))
print('Value of only G channel {}'.format(pic[ 100, 50, 1]))
print('Value of only B channel {}'.format(pic[ 100, 50, 2]))
# Out:
# Value of only R channel 0
# Value of only G channel 0
# Value of only B channel 0

# %%
# Testing with what should be a green pixel
print('Value of only R channel {}'.format(pic[ 80, 100, 0]))
print('Value of only G channel {}'.format(pic[ 80, 100, 1]))
print('Value of only B channel {}'.format(pic[ 80, 100, 2]))
# Out:
# Value of only R channel 15
# Value of only G channel 112
# Value of only B channel 19

# %%
plt.title('R channel')
plt.ylabel('Height {}'.format(pic.shape[0]))
plt.xlabel('Width {}'.format(pic.shape[1]))
plt.imshow(pic[ : , : , 0])
plt.show()

# %%
plt.title('G channel')
plt.ylabel('Height {}'.format(pic.shape[0]))
plt.xlabel('Width {}'.format(pic.shape[1]))
plt.imshow(pic[ : , : , 1])
plt.show()

# %%
plt.title('B channel')
plt.ylabel('Height {}'.format(pic.shape[0]))
plt.xlabel('Width {}'.format(pic.shape[1]))
plt.imshow(pic[ : , : , 2])
plt.show()

# %%
# FILE LOCATION VARIABLE FROM BEGINNING
# CHANGE AS NECESSARY IF ONLY RUNNING THIS CELL
pic=imageio.imread(file_location)
pic[50:150 , : , 0] =255# full intensity to those pixel's R channel
plt.figure( figsize= (10,10))
plt.imshow(pic)
plt.show()

# %%
pic[200:300 , : , 1] =255# full intensity to those pixel's G channel
plt.figure( figsize= (10,10))
plt.imshow(pic)
plt.show()

# %%
pic[350:450 , : , 2] =255# full intensity to those pixel's B channel
plt.figure( figsize= (10,10))
plt.imshow(pic)
plt.show()

# %%
# set value 200 of all channels to those pixels which turns them to white
pic[50:450 , 400:600 , [0,1,2] ] =200
plt.figure( figsize= (10,10))
plt.imshow(pic)
plt.show()

# %%
import numpy as np
# SAME AS BEFORE. CHANGE FILE LOCATION IF NEEDED.
pic=imageio.imread(file_location) 
fig,ax=plt.subplots(nrows=1,ncols=3,figsize=(15,5)) 
for c,ax in zip(range(3),ax): 
    # create zero matrix
    split_img=np.zeros(pic.shape,dtype="uint8")# 'dtype' by default: 'numpy.float64' 
    # assing each channel
    split_img[:,:,c]=pic[:,:,c]
    # display each channel
    ax.imshow(split_img)

# %%
# Y' = 0.299 R + 0.587 G + 0.114 B
pic=imageio.imread(file_location) 
gray=lambda rgb:np.dot(rgb[...,:3],[0.299,0.587,0.114])
gray=gray(pic) 
plt.figure(figsize=(10,10))
plt.imshow(gray,cmap=plt.get_cmap(name='gray'))
plt.show()

# %%
pic=imageio.imread(file_location) 
gray=lambda rgb:np.dot(rgb[...,:3],[0.21,0.72,0.07])
gray=gray(pic) 
plt.figure(figsize=(10,10))
plt.imshow(gray,cmap=plt.get_cmap(name='gray'))
plt.show()

# %%
print('Type of the image : ',type(gray))
print() 
print('Shape of the image : {}'.format(gray.shape))
print('Image Hight {}'.format(gray.shape[0]))
print('Image Width {}'.format(gray.shape[1]))
print('Dimension of Image {}'.format(gray.ndim))
print() 
print('Image size {}'.format(gray.size))
print('Maximum RGB value in this image {}'.format(gray.max()))
print('Minimum RGB value in this image {}'.format(gray.min()))
print('Random indexes [X,Y] : {}'.format(gray[100,50]))
# Out:
# Type of the image :  <class 'imageio.core.util.Array'>
#
# Shape of the image : (237, 237)
# Image Hight 237
# Image Width 237
# Dimension of Image 2
#
# Image size 56169
# Maximum RGB value in this image 254.99999999999997
# Minimum RGB value in this image 0.0
# Random indexes [X,Y] : 0.0
